# %%
# 引用自己的模組

from tool import get_soup
resp=get_soup('https://mops.twse.com.tw/mops/web/t05st10_ifrs')
resp
# Out:
# <!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.01 Transitional//EN" "http://www.w3.org/TR/html4/loose.dtd">
# <html>
# <head>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
# <title>公開資訊觀測站</title>
# <link href="css/print_css1.css" media="Print" rel="stylesheet" type="text/css"/>
# <link href="css/css2.css" rel="stylesheet" type="text/css"/>
# <link href="css/clickmenu1.css" rel="stylesheet" type="text/css"/>
# <!--
# <link href="css/tag.css" rel="stylesheet" type="text/css" />
# <link href="css/tablea.css" rel="stylesheet" type="text/css" />
# <script type="text/javascript" language="JavaScript1.2" src="js/menu/stmenu.js"></script>
# -->
# <!-- 2021.09.07 start 拿掉舊插件  -->
# <!-- <script type="text/javascript" src="js/jquery-1.1.4.pack.js"></script>
# <script type="text/javascript" src="js/jquery.clickmenu.js"></script> -->
# <!-- 2021.09.07 end 拿掉舊插件  -->
# <!-- 2021.09.07 start -->
# <script src="js/jquery-3.6.0.min.js" type="text/javascript"></script>
# <script src="js/mops2.js" type="text/javascript"></script>
# <!-- 2021.09.07 end -->
# </head>
# <body>
# <center>
# <table border="0"><tr><td align="left">
# <form action="/mops/web/ajax_autoComplete" method="post" name="fh" onsubmit="return false;" style="margin:0;"><input id="firstin" name="firstin" type="hidden" value="1"/><input id="TYPEK" name="TYPEK" type="hidden" value="all"/><input id="step" name="step" type="hidden" value="1"/><input name="co_id" type="hidden" value=""/><input name="funcName" type="hidden" value="t05st10_ifrs"/><input id="searchtype" name="searchtype" type="hidden" value=""/><input id="inpuType" name="inpuType" type="hidden" value="keyword"/><input id="auto-more" name="auto-more" type="hidden" value=""/><input name="keycon" type="hidden" value=""/><div id="head"><div id="head_02"><a alt="回首頁" href="/mops/web/index"><img border="0" height="52" src="images/blank.gif" width="232"/></a></div><div id="head_03"><div id="search_bar"><div id="nav"><a style="color:yellow;text-decoration:none;">全站搜尋</a></div><div align="left" id="search_b1"><table><tr><td align="left"><input autocomplete="off" class="textbox" id="keyword" name="keyword" onblur="setTimeout(function(){hideDiv('auto-complete-data');} , 200);" onclick="this.value='';document.getElementById('oldKeyWord').value='';hideDiv('auto-complete-data');" oninput="document.getElementById('auto-more').value='';autoComplete(this.form , 'keyword' , 'auto-complete-data' , event);" onkeydown='chkKeyDown(this.form , this , "auto-complete-data" , event);' onkeyup="document.getElementById('auto-more').value='';autoComplete(this.form , 'keyword' , 'auto-complete-data' , event);" placeholder="請輸入公司代號、簡稱，或報表關鍵字" size="45" type="text"/></td><td><input id="rulesubmit" name="rulesubmit" onclick="document.fh.action='/mops/web/autoAction';document.fh.submit();" type="button" value=" 搜尋 "/></td></tr></table></div><div class="search_b2" id="search_txt" style="z-index:1;"><table border="0"><tr><td><div style="background-image: url(images/map01.jpg) ; height: 19px; width:32px;background-position:-161px 0px;"></div></td><td><a href="javascript:void(0);" onclick='document.fh.keyword.value="營收";goaction("營收" , "0");'>營收</a><a href="javascript:void(0);" onclick='document.fh.keyword.value="除權息";goaction("除權息" , "0");'>除權息</a><a href="javascript:void(0);" onclick='document.fh.keyword.value="電子書";goaction("電子書" , "0");'>電子書</a><a href="javascript:void(0);" onclick='document.fh.keyword.value="法說會";goaction("法說會" , "0");'>法說會</a><a href="javascript:void(0);" onclick='document.fh.keyword.value="庫藏股";goaction("庫藏股" , "0");'>庫藏股</a><a href="javascript:void(0);" onclick='document.fh.keyword.value="董監持股";goaction("董監持股" , "0");'>董監持股</a><a href="javascript:void(0);" onclick='document.fh.keyword.value="獨立董事";goaction("獨立董事" , "0");'>獨立董事</a><a href="javascript:void(0);" onclick='document.fh.keyword.value="董監酬金";goaction("董監酬金" , "0");'>董監酬金</a><a href="javascript:void(0);" onclick='document.fh.keyword.value="ETF";goaction("ETF" , "0");'>ETF</a><a href="javascript:void(0);" onclick='document.fh.keyword.value="TDR";goaction("TDR" , "0");'>TDR</a></td></tr></table></div></div></div><div id="head_04"><a href="http://emops.twse.com.tw/emops_all.htm"><img border="0" height="32" src="images/blank.gif" width="89"/></a><p style="margin-left:11px;"><a href="https://mops.twse.com.tw/mops/web/ezsearch"><img border="0" src="images/blank.png"/></a></p></div></div></form><input id="oldKeyWord" type="hidden"/><div id="auto-complete-data"></div><div id="auto-complete-data2"></div><form action="" method="post" name="fh2" onsubmit="return false;" style="margin:0;"><input id="usually" name="usually" type="hidden" value=""/></form><script>window.onload=getMsg;    var MAR = document.querySelector("#marquee");     if(MAR){         var MARS = document.querySelectorAll("#marquee a");         for(var i=0;i<MARS.length;i++){             MARS[i].setAttribute("target","_blank");             MARS[i].setAttribute("style","margin-right:20px");         };         if(MARS.length<1){             MAR.parentNode.innerHTML = "<span style='color:#ff0;'>全站搜尋</span>";             MAR.setAt ...
# <div class="clickMenu" id="menu">
# <table border="0" cellpadding="0" cellspacing="0" width="100%">
# <!-- 2021.09.07 start -->
# <!-- <script>
# 			$(document).ready(function() {
#
# 				$('#list').clickMenu();
# 				document.getElementById('list').style.display='block';
# 			});
# 		</script> -->
# <!-- 2021.09.07 end  -->
# <tr>
# <td id="menu1">
# <ul id="list" style="display:none;">
# <li class="L00_Pop" id="mm0">常用報表
# 					</li>
# <li class="L00_Pop" id="mm1">基本資料
# 					</li>
# <li class="L00_Pop" id="mm2">彙總報表
# 					</li>
# <li class="L00_Pop" id="mm3">股東會及股利
# 					</li>
# <li class="L00_Pop" id="mm4">公司治理
# 					</li>
# <li class="L00_Pop" id="mm5">財務報表
# 					</li>
# <li class="L00_Pop" id="mm6">重大訊息與公告
# 					</li>
# <li class="L00_Pop" id="mm7">營運概況
# 					</li>
# <li class="L00_Pop" id="mm8">投資專區
# 					</li>
# <li class="L00_Pop" id="mm9">認購（售）權證
# 					</li>
# <li class="L00_Pop" id="mm10">債券
# 					</li>
# <li class="L00_Pop" id="mm11">資產證券化
# 					</li>
# </ul>
# </td>
# </tr>
# </table>
# </div>
# <div id="maincontent_in">
# <table border="0" cellpadding="0" cellspacing="0" width="100%">
# <tr>
# <td>
# <div id="PageBody">
# <table><tr><td style="height:400px" valign="top">
# <div id="main">
# <!--
# 程式設計師:tobey
# 程式名稱:submenu-7.htm
# 程式功能:submenu-7.htm
# 修改紀錄:(格式=>西元日期+版次+程式設計師)
# 2019092719hsin:(T88K)IFRSs後營收t05st10_ifrs放到IFRSs前
# 2019092723hsin:(T88G)IFRSs後營收t05st10_ifrs放到IFRSs前
# 2016072522oliver:(T88G)新增 t193sb01
# 2016072221oliver:(T88G)新增 t193sb03,t193sb04
# 2016042820thomas:(T88G)新增 t193sb02
# 2013081315kevin:(T88K)改標題,取得或處分資產之財務資料表 => 財務資料表, 母子公司交互資訊 => 母子公司交互資訊(自102年6月起免申報)
# 2013033014leo:(T88K)財務比率分析拆為IFRSs前後
# 2013013113:leo:(T88K)將開立發票及營業收入資訊為IFRS前、後，新增t05st10_ifrs
# 2013013012:leo:(T88K)修改 t12sc01_q3 搬移位置到 t12sc01_q1 上面
# 2012122911:tobey:(T88K)新增t05st22_q1，將財務比率分析拆為IFRS前後
# 20xxxxxx10:xxxx
# -->
# <table border="0" cellpadding="0" cellspacing="0" width="176">
# <tr>
# <td width="176"><span id="menu1" onclick="showhide('level7','img-7')" style="cursor: pointer; font-weight: bold; font-size: 13px;"> <img id="img-7" src="images/minus4.gif"/><a href="#">營運概況</a> </span> </td>
# </tr>
# <tr id="level7" style="display: inline;">
# <td style="padding-left: 10px;">
# <img id="img-7001" src="images/minus3.gif"/> <a href="#" onclick="showhide('level-7001','img-7001')" target="_self">每月營收</a><br/>
# <span id="level-7001" style="display: none;">
# <span style="padding-left: 15px;">
# <img src="images/pointer.gif"/><a href="t05st10_ifrs" target="_self">採用IFRSs後之月營<br/><span style="padding-left: 32px;">業收入資訊</span></a><br/>
# </span>
# <span style="padding-left: 15px;">
# <img src="images/pointer.gif"/><a href="t05st10" target="_self">採用IFRSs前之開立<br/><span style="padding-left: 32px;">發票及營業收入資訊</span></a><br/><span style="padding-left: 32px;">(含合併營收)</span><br/>
# </span>
# <span style="padding-left: 15px;">
# <img src="images/pointer.gif"/><a href="t05st08" target="_self">各項產品業務營收統<br/><span style="padding-left: 32px;">計表</span></a><br/>
# </span>
# </span>
# <img id="img-7002" src="images/minus3.gif"/> <a href="#" onclick="showhide('level-7002','img-7002')" target="_self">資金貸與及背書保證</a><br/>
# <span id="level-7002" style="display: none;">
# <span style="padding-left: 15px;">
# <img src="images/pointer.gif"/><a href="t05st11" target="_self">背書保證與資金貸放<br/><span style="padding-left: 30px;">餘額資訊</span></a><br/>
# </span>
# <span style="padding-left: 15px;">
# <img src="images/pointer.gif"/><a href="t65sb04" target="_self">資金貸與及背書保證<br/><span style="padding-left: 30px;">明細表資訊</span></a><br/>
# </span>
# </span>
# <img src="images/pointer.gif"/><a href="t79sb01">重要子公司月營收、背<br/><span style="padding-left: 15px;">書保證及資金貸放餘額</span></a><br/>
# <img id="img-7003" src="images/minus3.gif"/> <a href="#" onclick="showhide('level-7003','img-7003')" target="_self">關係人交易專區</a><br/>
# <span id="level-7003" style="display: none;">
# <span style="padding-left: 15px;">
# <img src="images/pointer.gif"/><a href="t05st11_q2" target="_self">背書保證與資金貸放<br/><span style="padding-left: 30px;">餘額明細</span></a><br/>
# </span>
# <span style="padding-left: 15px;">
# <img src="images/pointer.gif"/><a href="t65sb04_q2" target="_self">資金貸與及背書保證<br/><span style="padding-left: 30px;">明細表資訊</span></a><br/>
# </span>
# <span style="padding-left: 15px;">
# <img src="images/pointer.gif"/><a href="t79sb01_q2" target="_self">重要子公司月營收、<br/><span style="padding-left: 30px;">背書保證與資金貸放</span><br/><span style="padding-left: 30px;">餘額</span></a><br/>
# </span>
# <span style="padding-left: 15px;">
# <img src="images/pointer.gif"/><a href="t12sc01_q2" target="_self">月取得或處分資產資<br/><span style="padding-left: 30px;">訊</span></a><br/>
# </span>
# <span style="padding-left: 15px;">
# <img src="images/pointer.gif"/><a href="t141sb02" target="_self">與關係人取得處分資<br/><span style="padding-left: 30px;">產、進貨銷貨、應收</span><br/><span style="padding-left: 30px;">及應付款項相關資訊</span></a><br/>
# </span>
# <span style="padding-left: 15px;">
# <img src="images/pointer.gif"/><a href="t141sb03" target="_self">關係人交易申報數與<br/><span style="padding-left: 30px;">查核（核閱）數差異</span><br/><span style="padding-left: 30px;">說明</span></a><br/>
# </span>
# </span>
# <img src="images/pointer.gif"/><a href="t12sc01_q3">財務資料表</a><br/>
# <img src="images/pointer.gif"/><a href="t12sc01_q1">母子公司交互資訊(自<br/><span style="padding-left: 15px;">102年6月起免申報)</span></a><br/>
# <img id="img-7004" src="images/minus3.gif"/> <a href="#" onclick="showhide('level-7004','img-7004')" target="_self">赴大陸投資資訊</a><br/>
# <span id="level-7004" style="display: none;">
# <span style="padding-left: 15px;">
# <img src="images/pointer.gif"/><a href="t05st15" target="_self">赴大陸投資資訊(實<br/><span style="padding-left: 30px;">際數)</span></a><br/>
# </span>
# <span style="padding-left: 15px;">
# <img src="images/pointer.gif"/><a href="t92sb01" target="_self">赴大陸投資資訊(自<br/><span style="padding-left: 30px;">結數)</span></a><br/>
# </span>
# </span>
# <img id="img-7005" src="images/minus3.gif"/> <a href="#" onclick="showhide('level-7005','img-7005')" target="_self">投資海外子公司資訊</a><br/>
# <span id="level-7005" style="display: none;">
# <span style="padding-left: 15px;">
# <img src="images/pointer.gif"/><a href="t05st16" target="_self">投資海外子公司資訊<br/><span style="padding-left: 30px;">(實際數)</span></a><br/>
# </span>
# <span style="padding-left: 15px;">
# <img src="images/pointer.gif"/><a href="t92sb03" target="_self">投資海外子公司資訊<br/><span style="padding-left: 30px;">(自結數)</span></a><br/>
# </span>
# </span>
# <!--20121229 tobey sabrina begin: 修改 拆為IFRSs前後-->
# <!--
# 		<img src="images/minus3.gif" id="img-7006"/> <a onclick="showhide('level-7006','img-7006')" target="_self" href="#">財務比率分析</a><br/>
# 		<span style="display: none;" id="level-7006">
# 			<span style="padding-left: 15px;">
# 				<img src="images/pointer.gif"/><a target="_self" href="t12sc01_q3">取得或處分資產之財務資料表</a><br/>
# 			</span>
# 			<span style="padding-left: 15px;">
# 				<img src="images/pointer.gif"/><a target="_self" href="t05st24">營益分析表</a><br/>
# 			</span>
# 			<span style="padding-left: 15px;">
# 				<img src="images/pointer.gif"/><a target="_self" href="t05st22">財務分析資料</a><br/>
# 			</span>
# 			<span style="padding-left: 15px;">
# 				<img src="images/pointer.gif"/><a target="_self" href="t05st27">毛利率</a><br/>
# 			</span>
# 			<span style="padding-left: 15px;">
# 				<img src="images/pointer.gif"/><a target="_self" href="t05st25">存貨周轉率</a><br/>
# 			</span>
# 			<span style="padding-left: 15px;">
# 				<img src="images/pointer.gif"/><a target="_self" href="t05st26">應收帳款周轉率表</a><br/>
# 			</span>
# 		</span>
# -->
# <img id="img-7006" src="images/minus3.gif"/> <a href="#" onclick="showhide('level-7006','img-7006')" target="_self">財務比率分析</a><br/>
# <span id="level-7006" style="display: none;">
# <span style="padding-left: 15px;">
# <img id="img-7006001" src="images/minus3.gif"/>
# <a href="#" onclick="showhide('level-7006001','img-7006001')" target="_self">採IFRSs後</a><br/>
# <span id="level-7006001" style="display: none;">
# <span style="padding-left: 35px;">
# <img src="images/pointer.gif"/><a href="t163sb08" target="_self">營益分析表</a><br/>
# </span>
# <span style="padding-left: 35px;">
# <img src="images/pointer.gif"/><a href="t05st22_q1" target="_self">財務分析資料</a><br/>
# </span>
# <span style="padding-left: 35px;">
# <img src="images/pointer.gif"/><a href="t163sb09" target="_self">毛利率</a><br/>
# </span>
# <span style="padding-left: 35px;">
# <img src="images/pointer.gif"/><a href="t05st25_q1" target="_self">存貨週轉率</a><br/>
# </span>
# <span style="padding-left: 35px;">
# <img src="images/pointer.gif"/><a href="t05st26_q1" target="_self">應收帳款周轉率</a><br/>
# </span>
# </span>
# </span>
# <span style="padding-left: 15px;">
# <img id="img-7006002" src="images/minus3.gif"/>
# <a href="#" onclick="showhide('level-7006002','img-7006002')" target="_self">採IFRSs前</a><br/>
# <span id="level-7006002" style="display: none;">
# <span style="padding-left: 35px;">
# <img src="images/pointer.gif"/><a href="t05st24" target="_self">營益分析表</a><br/>
# </span>
# <span style="padding-left: 35px;">
# <img src="images/pointer.gif"/><a href="t05st22" target="_self">財務分析資料</a><br/>
# </span>
# <span style="padding-left: 35px;">
# <img src="images/pointer.gif"/><a href="t05st27" target="_self">毛利率</a><br/>
# </span>
# <span style="padding-left: 35px;">
# <img src="images/pointer.gif"/><a href="t05st25" target="_self">存貨周轉率</a><br/>
# </span>
# <span style="padding-left: 35px;">
# <img src="images/pointer.gif"/><a href="t05st26" target="_self">應收帳款周轉率表</a><br/>
# </span>
# </span>
# </span>
# </span>
# <!--20121229 tobey sabrina begin: 修改 拆為IFRSs前後-->
# <img src="images/pointer.gif"/><a href="t15sf">衍生性商品交易資訊</a><br/>
# <img id="img-7007" src="images/minus3.gif"/> <a href="#" onclick="showhide('level-7007','img-7007')" target="_self">自結損益公告</a><br/>
# <span id="level-7007" style="display: none;">
# <span style="padding-left: 15px;">
# <img src="images/pointer.gif"/><a href="t138sb02_q1" target="_self">自結損益公告-月申報</a><br/>
# </span>
# <span style="padding-left: 15px;">
# <img src="images/pointer.gif"/><a href="t138sb02_q2" target="_self">自結損益公告-季申報</a><br/>
# </span>
# </span>
# <img id="img-7008" src="images/minus3.gif"/> <a href="#" onclick="showhide('level-7008','img-7008')" target="_self">創業投資公司投資資訊</a><br/>
# <span id="level-7008" style="display: none;">
# <span style="padding-left: 15px;">
# <img src="images/pointer.gif"/><a href="t193sb01" target="_self">創業投資公司查詢</a><br/>
# </span>
# <span style="padding-left: 15px;">
# <img src="images/pointer.gif"/><a href="t193sb02" target="_self">創業投資公司每月投<br/><span style="padding-left: 30px;">資資訊</span></a><br/>
# </span>
# <span style="padding-left: 15px;">
# <img src="images/pointer.gif"/><a href="t193sb03" target="_self">創業投資公司每季投<br/><span style="padding-left: 30px;">資資訊-被投資公司</span><br/><span style="padding-left: 30px;">資訊</span></a><br/>
# </span>
# <span style="padding-left: 15px;">
# <img src="images/pointer.gif"/><a href="t193sb04" target="_self">未投資資金投資上市<br/><span style="padding-left: 30px;">（櫃）有價證券資訊</span></a><br/>
# </span>
# </span>
# </td>
# </tr>
# </table>
# </div>
# </td><td valign="top">
# <div id="sw"><div align="top" border="0" hspace="0" id="pic" name="pic" onclick="closex();" style="cursor: hand; background: url(images/map2.gif) no-repeat scroll 0% 0%; -moz-background-clip: border; -moz-background-origin: padding; -moz-background-inline-policy: continuous; height: 324px; width:14px;background-position:-542px 0px;" vspace="0"></div></div>
# </td><td valign="top">
# <div id="nav02">
# <div class="t0"></div>
# <div class="t01" id="caption"><br/>   採用IFRSs後之月營業收入資訊</div>
# <div id="bar01">
# <form action="/mops/web/ajax_t05st10_ifrs" id="form1" method="post" name="form1" onsubmit="return false;">
# <input id="subMenuID" type="hidden" value="[7,7001]"/>
# <table border="0" cellpadding="0" cellspacing="0" width="775">
# <tr>
# <td class="bar01a" valign="top" width="6px"><div style="background: url(images/map2.gif) no-repeat scroll 0% 0%; -moz-background-clip: border; -moz-background-origin: padding; -moz-background-inline-policy: continuous; height: 52px; width:6px;background-position:1px 0px;"></div></td>
# <td class="bar01b" valign="top"><!--
# 程式設計師:不明
# 程式名稱:query-7.htm
# 修改紀錄:(格式=>西元日期+版次+程式設計師)
# 2016121211oliver:(T88K)修正Safari自動完成Bug
# 2016030610edward:(T88K)移除公司代號搜尋
# -->
# <!-- 最新/歷史資料, 公司代號, 年度, 月份 -->
# <input name="step" type="hidden" value="1"/>
# <input name="firstin" type="hidden" value="ture"/>
# <input name="off" type="hidden" value="1"/>
# <table border="0" cellpadding="2" cellspacing="0">
# <input name="keyword4" type="hidden"/>
# <input name="code1" type="hidden"/>
# <input name="TYPEK2" type="hidden"/>
# <input name="checkbtn" type="hidden"/>
# <input name="queryName" type="hidden" value="co_id"/>
# <input name="inpuType" type="hidden" value="co_id"/>
# <tr>
# <input name="TYPEK" type="hidden" value="all"/>
# <td><div id="div4" style="background: url(images/map2.gif) no-repeat scroll 0% 0%; -moz-background-clip: border; -moz-background-origin: padding; -moz-background-inline-policy: continuous; height: 11px; width:11px;background-position:-345px 0px;"></div></td>
# <td><div id="search_bar1">
# <div class="search">
# <select id="isnew" name="isnew"><option value="true">最新資料</option><option value="false">歷史資料</option></select>
# </div>
# </div></td>
# <td><div id="div4" style="background: url(images/map2.gif) no-repeat scroll 0% 0%; -moz-background-clip: border; -moz-background-origin: padding; -moz-background-inline-policy: continuous; height: 11px; width:11px;background-position:-345px 0px;"></div></td><td>公司代號<span style="color:red;">或簡稱</span></td>
# <td><div id="search_bar1">
# <div class="search">
# <input autocomplete="off" class="textbox" id="co_id" name="co_id" onblur="setTimeout(function(){hideDiv('auto-complete-data');} , 200);" onclick="this.value='';document.getElementById('oldKeyWord').value='';hideDiv('auto-complete-data');" oninput="autoComplete(this.form , 'co_id' , 'auto-complete-data' , event);" onkeydown="{if(event.keyCode==13){document.getElementById('year').focus(); hideDiv2(this); return false;}else{chkKeyDown(document.form1 , this , 'auto-complete-data' , event);}}" onkeyup="autoComplete(this.form , 'co_id' , 'auto-complete-data' , event);" size="10" type="text" value=""/>
# </div>
# </div></td>
# <!--
# 			<td><div id="search_bar1">
# 				<div class="search">
# 					<input type="button" value="代號查詢" onclick="showsh2('quicksearch9','showTable9');document.form1.step.value='4';action='/mops/web/ajax_quickpgm';ajax1(this.form,'quicksearch9');">
# 				</div>
# 			</div></td>
# -->
# <td><div id="div4" style="background: url(images/map2.gif) no-repeat scroll 0% 0%; -moz-background-clip: border; -moz-background-origin: padding; -moz-background-inline-policy: continuous; height: 11px; width:11px;background-position:-345px 0px;"></div></td><td>年度</td>
# <td><div id="search_bar1">
# <div class="search">
# <input class="textbox" id="year" maxlength="3" name="year" onkeydown="{if(event.keyCode==13){document.getElementById('month').focus(); return false;}}" size="3" type="text" value=""/>
# </div>
# </div></td>
# <td><div id="div4" style="background: url(images/map2.gif) no-repeat scroll 0% 0%; -moz-background-clip: border; -moz-background-origin: padding; -moz-background-inline-policy: continuous; height: 11px; width:11px;background-position:-345px 0px;"></div></td><td>月份</td>
# <td><div id="search_bar1">
# <div class="search">
# <select id="month" name="month">
# <option value=""></option>
# <option value="01">1</option>
# <option value="02">2</option>
# <option value="03">3</option>
# <option value="04">4</option>
# <option value="05">5</option>
# <option value="06">6</option>
# <option value="07">7</option>
# <option value="08">8</option>
# <option value="09">9</option>
# <option value="10">10</option>
# <option value="11">11</option>
# <option value="12">12</option>
# </select>
# </div>
# </div></td>
# </tr>
# </table>
# </td>
# <td align="right" class="bar01b"> </td>
# <td align="right" class="bar01b" valign="top">
# <table border="0" cellpadding="2" cellspacing="0">
# <tr>
# <td>   </td>
# <td><div id="search_bar1">
# <div class="search">
# <input onclick="javascript:doAction();ajax1(document.form1,'table01');" type="button" value=" 查詢 "/>
# </div>
# </div></td>
# </tr>
# </table>
# </td>
# <td class="bar01a" valign="top" width="6px"><div style="background: url(images/map2.gif) no-repeat scroll 0% 0%; -moz-background-clip: border; -moz-background-origin: padding; -moz-background-inline-policy: continuous; height: 52px; width:6px;background-position:-72px 0px;"></div></td>
# </tr>
# </table>
# </form>
# </div>
# <div id="table_ess">
# <table border="0" cellpadding="2" cellspacing="0" id="showTable9">
# <tr>
# <th align="left" width="80px"><a href="javascript:outputNewWindowPrint();"><img alt="列印網頁" border="0" src="images/bu_01.gif"/></a></th><th width="80px"><a href="javascript:outputNewWindow();"><img alt="開新視窗" border="0" src="images/bu_02.gif"/></a></th><th width="80px"><a href="javascript:reportError();"><img alt="問題回報" border="0" src="images/bu_04.gif"/></a></th><th width="80px"><a href="javascript:void(0)" id="ajax_back_button" onclick="ajax_back();" style="visibility:hidden;"></a></th>
# <th><table border="0" cellpadding="0" cellspacing="0">
# <tr>
# <td width="650px"></td>
# </tr>
# </table></th>
# </tr>
# </table>
# </div>
# <div id="zoom"><div id="table01"></div>
# <br/></div>
# </div></td></tr></table>
# </div></td></tr>
# </table>
# </div>
# <div id="footer">
# <table border="0" cellpadding="0" cellspacing="0" width="100%">
# <tr>
# <th>
# <div align="center" class="text1" id="text1">
# <a href="https://www.stockvote.com.tw/" target="_blank">電子投票</a>│
# 			<a href="http://www.sfb.gov.tw/Layout/main_ch/index.aspx?frame=5" target="_blank">不繼續公開發行</a>│
# 			<a href="/server-java/t39sb01" target="_blank">市場公告</a>│
#
#
# 			<a href="https://www.sfi.org.tw/cga/cga1" target="_blank">公司治理評鑑</a>│
#
#
#
#
#
# 			<a href="/mops/web/t146sb08">網站地圖</a>│
# 			<a href="/nas/MOPS_HandBook.doc" target="_MOPS_handbook">網站使用說明</a>
# <div align="center" class="text1" height="80" id="text1">
# <a href="#">投資人服務中心(02)2792-8188</a> <u><a href="http://Suggestionbox.twse.com.tw" target="_blank">聯絡我們</a></u>
# </div>
# </div>
# </th>
# </tr>
# </table>
# </div>
# </td></tr></table></center>
# <div id="quicksearch9" style="position:absolute;z-index:3;overflow:auto;width:620px;max-height:200px;display:none;"></div>
# </body>
# <script>
# function doAction() {
# 	if (document.form1.step!=null && document.form1.step!=undefined && document.form1.step.value!='')
# 	{
# 		if (document.form1.step.value!='0')
# 		{
# 			document.form1.step.value='1';
# 		}
# 	}
# 	if (document.form1.firstin!=null && document.form1.firstin!=undefined && document.form1.firstin.value!='')
# 	{
# 		document.form1.firstin.value='1';
# 	}
# 	var name=document.fh.funcName.value;
# 	document.form1.action='/mops/web/ajax_'+name;
# }
# function checkAutoRunScript(){
# 	if (document.autoForm!=null && document.autoForm!=undefined && document.autoForm.run.value==''){
# 		document.autoForm.run.value='Y';
# 		ajax1(document.autoForm,'table01');
# 	}
#
# 	if (document.autoRunScript!=null && document.autoRunScript!=undefined && document.autoRunScript.run.value!=''){
# 		var s = document.autoRunScript.run.value;
# 		document.autoRunScript.run.value = '';
# 		new function(){
# 			eval(s);
# 		};
# 	}
#
# }
#
# setInterval("checkAutoRunScript()",100);
# </script>
# <!-- 2021.09.07 start -->
# <script>
# 	function listinnerli(){
# 		if(document.querySelector('#mm0'))document.querySelector('#mm0').innerHTML = menu0;
# 		if(document.querySelector('#mm1'))document.querySelector('#mm1').innerHTML = menu1;
# 		if(document.querySelector('#mm2'))document.querySelector('#mm2').innerHTML = menu2;
# 		if(document.querySelector('#mm3'))document.querySelector('#mm3').innerHTML = menu3;
# 		if(document.querySelector('#mm4'))document.querySelector('#mm4').innerHTML = menu4;
# 		if(document.querySelector('#mm5'))document.querySelector('#mm5').innerHTML = menu5;
# 		if(document.querySelector('#mm6'))document.querySelector('#mm6').innerHTML = menu6;
# 		if(document.querySelector('#mm7'))document.querySelector('#mm7').innerHTML = menu7;
# 		if(document.querySelector('#mm8'))document.querySelector('#mm8').innerHTML = menu8;
# 		if(document.querySelector('#mm9'))document.querySelector('#mm9').innerHTML = menu9;
# 		if(document.querySelector('#mm10'))document.querySelector('#mm10').innerHTML = menu10;
# 		if(document.querySelector('#mm11'))document.querySelector('#mm11').innerHTML = menu11;
# 		if(document.querySelector('#mm12'))document.querySelector('#mm12').innerHTML = menu12;
# 	}
# 	window.onload = listinnerli;
# </script>
# <!-- 2021.09.07 end -->
# </html>

# %%
# 觀察輸入代碼並按查詢後，網址都不變，推測為API post method
# 請由「開發者工具」觀察其api網址及form_data

stk = '2330'

api_url = 'https://mops.twse.com.tw/mops/web/ajax_t05st10_ifrs'

form_data = {'strTargetField': 'COUNTY',
             'strKeyWords': '基隆市'}

# %%
# 由使用者輸入任意數量的公司代碼

cos = []

while True:
    co = input('請輸入公司代碼：（按Enter結束）')
    if co == '':
        break
    else:
        cos.append(co)

cos

# %%
soup = get_soup(api_url, form_data)
soup

# %% [markdown]
# 欄位：公司代號、公司名稱、本月營收金額、增減百分比（本月）、增減百分比（累計）
